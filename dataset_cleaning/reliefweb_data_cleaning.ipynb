# %%
import pandas as pd

# %%
df = pd.read_csv("reliefweb-disasters-list.csv")
df
# Out:
#            id                                               name  \
# 0    #meta+id                                       #crisis+name
# 1       52176  Rwanda: Marburg Virus Disease Outbreak - Sep 2024
# 2       52173                            Togo: Floods - Aug 2024
# 3       52171                    Sierra Leone: Floods - Sep 2024
# 4       52169             Cabo Verde: Dengue Outbreak - Jun 2024
# ..        ...                                                ...
# 889     28186                            Iraq: Floods - Oct 2015
# 890     27771                        Ethiopia: Floods - Oct 2015
# 891     27741        Afghanistan/Pakistan: Earthquake - Oct 2015
# 892     27706                         Algeria: Floods - Oct 2015
# 893     27576                         Somalia: Floods - Oct 2015
#
#                                            description        status  \
# 0                                         #description  #status+name
# ...
